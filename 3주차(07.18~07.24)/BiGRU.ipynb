# 1215744  -1.02050 -0.471980  -0.98056  9.663600  3.493900         0  subject10
#
# [1215745 rows x 23 columns]

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['acc_ch_x', 'acc_ch_y', 'acc_ch_z', 'acc_la_x', 'acc_la_y', 'acc_la_z',
#        'gyr_la_x', 'gyr_la_y', 'gyr_la_z', 'mag_la_x', 'mag_la_y', 'mag_la_z',
#        'acc_rw_x', 'acc_rw_y', 'acc_rw_z', 'gyr_rw_x', 'gyr_rw_y', 'gyr_rw_z',
#        'mag_rw_x', 'mag_rw_y', 'mag_rw_z', 'activity', 'subject'],
#       dtype='object')

# %% [markdown]
# ### acc_ch_x, acc_ch_y, acc_ch_z: 가슴 부위의 가속도계 X, Y, Z 축 데이터
# ### acc_la_x, acc_la_y, acc_la_z: 왼팔 부위의 가속도계 X, Y, Z 축 데이터
# ### gyr_la_x, gyr_la_y, gyr_la_z: 왼팔 부위의 자이로스코프 X, Y, Z 축 데이터
# ### mag_la_x, mag_la_y, mag_la_z: 왼팔 부위의 자력계 X, Y, Z 축 데이터
# ### acc_rw_x, acc_rw_y, acc_rw_z: 오른쪽 손목 부위의 가속도계 X, Y, Z 축 데이터
# ### gyr_rw_x, gyr_rw_y, gyr_rw_z: 오른쪽 손목 부위의 자이로스코프 X, Y, Z 축 데이터
# ### mag_rw_x, mag_rw_y, mag_rw_z: 오른쪽 손목 부위의 자력계 X, Y, Z 축 데이터
# ### activity: 수행된 활동의 유형
# ### subject: 데이터를 수집한 대상 (피험자)

# %% [markdown]
# ## @여기서 subject를 제외했습니다.subject 값이 문자로 나와서 제외 했습니다

# %%
df = df[['acc_ch_x', 'acc_ch_y', 'acc_ch_z', 'acc_la_x', 'acc_la_y', 'acc_la_z','gyr_la_x', 'gyr_la_y', 'gyr_la_z', 'mag_la_x', 'mag_la_y', 'mag_la_z','acc_rw_x', 'acc_rw_y', 'acc_rw_z', 'gyr_rw_x', 'gyr_rw_y', 'gyr_rw_z','mag_rw_x', 'mag_rw_y', 'mag_rw_z', 'activity']]

# %%
# 레이블 갯수 확인 (숫자)
df['activity'].value_counts()
# Out:
# activity
# 0     872550
# 1      30720
# 2      30720
# 3      30720
# 4      30720
# 9      30720
# 10     30720
# 11     30720
# 5      30720
# 7      29441
# 8      29337
# 6      28315
# 12     10342
# Name: count, dtype: int64

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# acc_ch_x    0
# acc_ch_y    0
# acc_ch_z    0
# acc_la_x    0
# acc_la_y    0
# acc_la_z    0
# gyr_la_x    0
# gyr_la_y    0
# gyr_la_z    0
# mag_la_x    0
# mag_la_y    0
# mag_la_z    0
# acc_rw_x    0
# acc_rw_y    0
# acc_rw_z    0
# gyr_rw_x    0
# gyr_rw_y    0
# gyr_rw_z    0
# mag_rw_x    0
# mag_rw_y    0
# mag_rw_z    0
# activity    0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# acc_ch_x    0
# acc_ch_y    0
# acc_ch_z    0
# acc_la_x    0
# acc_la_y    0
# acc_la_z    0
# gyr_la_x    0
# gyr_la_y    0
# gyr_la_z    0
# mag_la_x    0
# mag_la_y    0
# mag_la_z    0
# acc_rw_x    0
# acc_rw_y    0
# acc_rw_z    0
# gyr_rw_x    0
# gyr_rw_y    0
# gyr_rw_z    0
# mag_rw_x    0
# mag_rw_y    0
# mag_rw_z    0
# activity    0
# dtype: int64

# %% [markdown]
# ## 다음과 같이 설정
# ### x=activity를 제외한 나머지
# ### y=activity

# %%
X=df.drop('activity',axis=1)
X.head()
# Out:
#    acc_ch_x  acc_ch_y  acc_ch_z  acc_la_x  acc_la_y  acc_la_z  gyr_la_x  \
# 0   -9.8184  0.009971   0.29563    2.1849   -9.6967   0.63077  0.103900
# 1   -9.8489  0.524040   0.37348    2.3876   -9.5080   0.68389  0.085343
# 2   -9.6602  0.181850   0.43742    2.4086   -9.5674   0.68113  0.085343
# 3   -9.6507  0.214220   0.24033    2.1814   -9.4301   0.55031  0.085343
# 4   -9.7030  0.303890   0.31156    2.4173   -9.3889   0.71098  0.085343
#
#    gyr_la_y  gyr_la_z  mag_la_x  ...  mag_la_z  acc_rw_x  acc_rw_y  acc_rw_z  \
# 0  -0.84053  -0.68762 -0.370000  ...   0.29963   -8.6499   -4.5781  0.187760
# 1  -0.83865  -0.68369 -0.197990  ...   0.58298   -8.6275   -4.3198  0.023595
# 2  -0.83865  -0.68369 -0.374170  ...   0.43851   -8.5055   -4.2772  0.275720
# 3  -0.83865  -0.68369 -0.017271  ...   0.57571   -8.6279   -4.3163  0.367520
# 4  -0.83865  -0.68369 -0.374390  ...   0.44586   -8.7008   -4.1459  0.407290
#
#    gyr_rw_x  gyr_rw_y  gyr_rw_z  mag_rw_x  mag_rw_y  mag_rw_z
# 0  -0.44902   -1.0103  0.034483  -2.35000 -1.610200 -0.030899
# 1  -0.44902   -1.0103  0.034483  -2.16320 -0.882540  0.326570
# 2  -0.44902   -1.0103  0.034483  -1.61750 -0.165620 -0.030693
# 3  -0.45686   -1.0082  0.025862  -1.07710  0.006945 -0.382620
# 4  -0.45686   -1.0082  0.025862  -0.53684  0.175900 -1.095500
#
# [5 rows x 21 columns]

# %%
y=df['activity']
y.value_counts()
# Out:
# activity
# 0     872550
# 1      30720
# 2      30720
# 3      30720
# 4      30720
# 9      30720
# 10     30720
# 11     30720
# 5      30720
# 7      29441
# 8      29337
# 6      28315
# 12     10342
# Name: count, dtype: int64

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: activity, dtype: int64

# %% [markdown]
# #### train_test_split 함수는 데이터를 학습용과 테스트용으로 나누는 데 사용됩니다.
# #### 이 함수는 scikit-learn에서 제공하며, 데이터셋을 무작위로 분할하고, 필요한 경우 분할 비율을 지정할 수 있습니다

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.1, 
                                                    shuffle = True, 
                                                    random_state = 21)

# %% [markdown]
# #### split_sequences 함수는 시퀀스 데이터를 특정 길이의 패턴으로 나누어 모델 학습에 적합한 형태로 변환하는 함수

# %%
def split_sequences(sequences, n_steps):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the dataset
		if end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
# Merge train and test X/y data to apply sequence transformation function
y_train_array = np.array(y_train)
train_set = np.c_[X_train, y_train_array]

y_test_array = np.array(y_test)
test_set = np.c_[X_test, y_test_array]

# Apply sequence transformation using time step of 25 for both train and test data
# All sensing modalities are recorded at a sampling rate of 50 Hz, which is considered sufficient for capturing human activity.

X_train, y_train = split_sequences(train_set, 5)
print(X_train.shape, y_train.shape)

X_test, y_test = split_sequences(test_set, 5)
print(X_test.shape, y_test.shape)
# Out:
# (1094166, 5, 21) (1094166,)
# (121571, 5, 21) (121571,)

# %%
y_train_onehot = pd.get_dummies(y_train).values
y_test_onehot = pd.get_dummies(y_test).values

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Input
from keras.layers import Dense, Flatten, Dropout

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_onehot.shape[1]

# %% [markdown]
# ## BiGRU 모델 정의
# #### BiGRU 모델을 정의할 때, Bidirectional 레이어를 사용하여 양방향 GRU 레이어를 추가합니다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, Bidirectional

# BiGRU 모델 정의
model = Sequential()

# Bidirectional GRU 레이어 추가
model.add(Bidirectional(GRU(units=100, return_sequences=True), input_shape=(n_timesteps, n_features)))
model.add(Dropout(0.5))

# GRU 레이어 추가 (Bidirectional GRU와는 별개로 추가)
model.add(GRU(units=50))  # return_sequences=False는 기본값
model.add(Dropout(0.5))

# Dense 레이어 추가
model.add(Dense(64, activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))  # 클래스 수에 맞춘 출력 레이어

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 요약
model.summary()
# Out:
# C:\Users\PC\anaconda3\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 5, 200)              │          73,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 5, 200)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 50)                  │          37,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           3,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 13)                  │             845 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 115,709 (451.99 KB)
#  Trainable params: 115,709 (451.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 모델 학습

# %%
history = model.fit(X_train, y_train_onehot, epochs=30, verbose=1, validation_split=0.1)
# Out:
# Epoch 1/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 176s 5ms/step - accuracy: 0.7443 - loss: 0.7641 - val_accuracy: 0.7890 - val_loss: 0.5038
# Epoch 2/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 175s 6ms/step - accuracy: 0.7739 - loss: 0.5583 - val_accuracy: 0.7974 - val_loss: 0.4772
# Epoch 3/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 175s 6ms/step - accuracy: 0.7845 - loss: 0.5290 - val_accuracy: 0.8014 - val_loss: 0.4712
# Epoch 4/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 151s 5ms/step - accuracy: 0.7900 - loss: 0.5130 - val_accuracy: 0.8012 - val_loss: 0.4679
# Epoch 5/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 150s 5ms/step - accuracy: 0.7932 - loss: 0.5069 - val_accuracy: 0.8040 - val_loss: 0.4587
# Epoch 6/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 152s 5ms/step - accuracy: 0.7966 - loss: 0.4973 - val_accuracy: 0.8061 - val_loss: 0.4585
# Epoch 7/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 155s 5ms/step - accuracy: 0.7979 - loss: 0.4955 - val_accuracy: 0.8076 - val_loss: 0.4524
# Epoch 8/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 156s 5ms/step - accuracy: 0.7991 - loss: 0.4955 - val_accuracy: 0.8001 - val_loss: 0.4594
# Epoch 9/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 145s 5ms/step - accuracy: 0.7993 - loss: 0.4939 - val_accuracy: 0.8093 - val_loss: 0.4564
# Epoch 10/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━ 150s 5ms/step - accuracy: 0.8003 - loss: 0.4941 - val_accuracy: 0.8093 - val_loss: 0.4499
# Epoch 11/30
# 30774/30774 ━━━━━━━━━━━━━━━━━━━━